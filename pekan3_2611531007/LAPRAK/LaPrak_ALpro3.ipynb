# %% [markdown]
# <div align="center">
#
# <h1 style="font-size: 18px;"> <b>LAPORAN PRAKTIKUM</b></h1>
# <h2 style="font-size: 18px;"> <b>ALGORITMA DAN PEMROGRAMAN</b></h2>
# <h2 style="font-size: 18px;"> <b>"Operator pada Python"</b></h2>
# <h4 style="font-size: 16px;"> <b>Disusun Oleh: </b></h4>
# <h4 style="font-size: 16px; "> <b>Muhammad Rasya Fahrozi</b> </h4>
# <h4 style="font-size: 16px; "> <b>2611531007</b><h4>
# <h4 style="font-size: 16px;"> <b>Dosen Pengampu:</b></h4>
# <h4 style="font-size: 16px; "> <b>Dr. Ir. Wahyudi, S.T., M.T.</b> </h4>
# <h4 style="font-size: 16px;"> <b>Asisten Praktikum: </b></h4>
# <h4 style="font-size: 16px;"> <b>Muhammad Galid Avero</b></h4>
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# <h4 style="font-size: 16px;"> <b>FAKULTAS TEKNOLOGI INFORMASI</b></h4>
# <h4 style="font-size: 16px; "> <b>DEPARTEMEN INFORMATIKA</b> </h4>
# <h4 style="font-size: 16px;"> <b>UNIVERSITAS ANDALAS </b></h4>
# <h4 style="font-size: 16px;"> <b>2026</b></h4>
#
# </div>

# %% [markdown]
# ## <h1 align = "center">KATA PENGANTAR <h1>
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan pratikum pengenalan pyhton, vs code, dan koneksi ke github yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Algoritma dan Pemrograman. Praktikum ini berfokus pada pembahasan pengenalan pyhton, vs code, dan koneksi ke github.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep dasar pemrograman Python pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026
#
# Hormat Saya
#
# (Muhammad Rasya Fahrozi)

# %% [markdown]
# ---
# # <h1 align = "center">BAB I <h1>
# # <h1 align = "center">PENDAHULUAN<h1>
#
# ## 1.1 Latar Belakang
# Dalam pengembangan sebuah program, data saja tidak cukup untuk menghasilkan suatu proses atau keputusan, dibutuhkan operator sebagai simbol khusus yang memproses nilai-nilai atau operand tersebut menjadi informasi baru. Pada praktikum sebelumnya, mahasiswa telah mempelajari variabel dan tipe data sebagai wadah penyimpanan nilai dalam Python. Materi operator menjadi kelanjutan yang penting, karena hampir seluruh logika program mulai dari perhitungan sederhana, pengambilan keputusan, hingga manipulasi data tingkat bit dibangun di atas berbagai jenis operator.
#
# Python menyediakan tujuh kelompok operator, yaitu aritmatika, penugasan, perbandingan, logika, keanggotaan, identitas, dan bitwise, yang masing-masing memiliki fungsi dan konteks penggunaan berbeda. Oleh karena itu, pemahaman konseptual sekaligus praktik langsung terhadap ketujuh operator ini menjadi kebutuhan mendasar sebelum mahasiswa melanjutkan ke struktur kontrol dan logika program yang lebih kompleks.
#
# Untuk mendalami penerapan operator secara terintegrasi, praktikum pekan ini mengangkat studi kasus sistem simulasi transaksi dan validasi akses toko. Studi kasus ini dipilih karena merepresentasikan permasalahan nyata di dunia kasir/retail, di mana sebuah program perlu memvalidasi status pelanggan, menghitung nilai transaksi, memeriksa keabsahan kode promo, hingga menentukan hak akses pelanggan berdasarkan kombinasi beberapa kondisi — sehingga seluruh jenis operator Python dapat diterapkan secara bermakna dalam satu alur program yang utuh.
#
# ## 1.2 Tujuan
# 1. Memahami dan mampu menerapkan berbagai jenis operator pada bahasa pemrograman Python, meliputi operator aritmatika, perbandingan, logika, penugasan, keanggotaan, identitas, dan bitwise.
# 2. Bisa mempraktikkan semua operator tersebut dalam satu program nyata yang saling berkaitan
# 3. Memahami cara kerja operator dalam Python dan kapan masing-masing jenis digunakan dalam sebuah program.
#
# ## 1.3 Manfaat
# 1. Dapat membedakan penggunaan operator yang tepat sesuai kebutuhan logika program, misalnya kapan menggunakan operator perbandingan dan kapan menggunakan operator logika untuk menggabungkan beberapa kondisi.
# 2. Menjelaskan tiap program yang dibuat dari setiap operator.
# 3. Memperoleh pengalaman langsung dalam menyelesaikan permasalahan teknis.

# %% [markdown]
# ---
# # <h1 align = "center">BAB II <h1>
# ## <h1 align = "center">PEMBAHASAN <h1>
#
# ## 2.1 Dasar Teori
#
# Operator adalah simbol khusus dalam Python yang digunakan untuk menjalankan suatu operasi terhadap satu atau lebih nilai (operand), sehingga menghasilkan sebuah nilai baru (Jago Ngoding, 2021). Python menyediakan tujuh kelompok operator: aritmatika, penugasan, perbandingan, logika, keanggotaan, identitas, dan bitwise (RevoU, 2024). Berikut penjelasan rinci masing-masing:
#
# ### 2.1.1 Operator Aritmatika.
# Digunakan untuk operasi matematika dasar (Ediweb.dev, 2024). Terdiri dari + (penjumlahan), - (pengurangan), * (perkalian), / (pembagian, hasil selalu pecahan/float), // (pembagian bulat/floor division, hasil dibulatkan ke bawah), % (modulus, mengambil sisa hasil bagi), dan ** (perpangkatan).
#
# ### 2.1.2 Operator Penugasan.
# Digunakan untuk memberikan atau memperbarui nilai suatu variabel (Jago Ngoding, 2021). Bentuk paling dasar adalah =. Selain itu tersedia bentuk augmented assignment yang menggabungkan operasi aritmatika sekaligus penugasan ulang, yaitu +=, -=, *=, /=, %=, //=, dan **=.
#
# ### 2.1.3 Operator Perbandingan.
# Digunakan untuk membandingkan dua operand dan selalu menghasilkan nilai boolean, True atau False (DQLab, 2021). Terdiri dari == (sama dengan), != (tidak sama dengan), > (lebih besar), < (lebih kecil), >= (lebih besar atau sama dengan), dan <= (lebih kecil atau sama dengan).
#
# ### 2.1.4 Operator Logika.
# Digunakan untuk menggabungkan atau membalik beberapa ekspresi boolean, dan sangat berkaitan erat dengan operator perbandingan karena sama-sama menghasilkan nilai boolean (Jago Ngoding, 2021). Terdiri dari and (bernilai True hanya jika kedua kondisi benar), or (bernilai True jika salah satu kondisi benar), dan not (membalik nilai boolean suatu kondisi).
#
# ### 2.1.5 Operator Keanggotaan.
# Digunakan untuk memeriksa apakah suatu nilai terdapat di dalam sebuah struktur data seperti list, tuple, atau string. Terdiri dari in (bernilai True jika nilai ditemukan) dan not in (bernilai True jika nilai tidak ditemukan).
#
# ### 2.1.6 Operator Identitas.
# Digunakan untuk membandingkan identitas dua objek, yaitu apakah keduanya menunjuk ke lokasi memori yang sama persis, bukan sekadar nilainya sama. Terdiri dari is dan is not. Berbeda dengan == yang membandingkan isi/nilai, is membandingkan alamat objek di memori. Dua variabel list dengan isi identik namun dibuat secara terpisah akan menghasilkan is bernilai False, meskipun == tetap bernilai True.
#
# ### 2.1.7 Operator Bitwise.
# Digunakan untuk mengolah data dalam bentuk representasi biner (bit demi bit), dan biasa dipakai untuk membangun rangkaian logika seperti AND, OR, atau XOR pada tingkat bit, misalnya untuk keperluan flag atau kode status suatu sistem (Duniailkom, 2019; Anbidev, 2019). Operator ini meliputi & (AND, hasil bit bernilai 1 hanya jika kedua bit bernilai 1), | (OR, hasil bit bernilai 1 jika salah satu bit bernilai 1), ^ (XOR, hasil bit bernilai 1 jika kedua bit berbeda), ~ (NOT, membalik seluruh bit), << (shift kiri, menggeser bit ke kiri sejumlah posisi tertentu, setara mengalikan dengan pangkat dua), dan >> (shift kanan, menggeser bit ke kanan, setara membagi dengan pangkat dua).

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program Operator Aritmatika "A_2611531007"

# %%
#Buat file dengan nama aritmatika_NIM.py
#Buat program untuk operator aritmatika dalam Python
#Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
#Program ini menggunakan fungsi input ()
#Nilai yang dimasukkan akan dikonversi menjadi tipe data integer

angka1_1007 = int(input("Input angka-1: "))
angka2_1007 = int(input("Input angka-2: "))

#Penjumalahan 
hasil_1007 = angka1_1007 + angka2_1007
print("\nOperator Penjumlahan")
print("Hasil =", hasil_1007)

#Pemgurangan
hasil_1007 = angka1_1007 - angka2_1007
print("\nOperator Pengurangan")
print("Hasil =", hasil_1007)

#Perkalian
hasil_1007 = angka1_1007 * angka2_1007
print("\nOperator Perkalian")
print("Hasil =", hasil_1007)

#Pembagian, pembagian bulat, dan sisa bagi
if angka2_1007 != 0:
    hasil_1007 = angka1_1007 / angka2_1007
    print("\nOperator Pembagian")
    print("Hasil =", hasil_1007)

    hasil_1007 = angka1_1007 // angka2_1007
    print("\nOperator Pembagian Bulat")
    print("Hasil =", hasil_1007)

    hasil = angka1_1007 % angka2_1007
    print("\nOperator Sisa Bagi")
    print("Hasil =", hasil_1007)
else:
    print("Angka kedua tidak bole bernilai 0.")

#Pangkat
hasil_1007 = angka1_1007 ** angka2_1007
print("\nOperator Pangkat")
print("Hasil =", hasil_1007)
# Out:
# Operator Penjumlahan
# Hasil = 8
#
# Operator Pengurangan
# Hasil = -2
#
# Operator Perkalian
# Hasil = 15
#
# Operator Pembagian
# Hasil = 0.6
#
# Operator Pembagian Bulat
# Hasil = 0
#
# Operator Sisa Bagi
# Hasil = 0
#
# Operator Pangkat
# Hasil = 243

# %% [markdown]
# Penjelasan Program:
#
# 1. Baris 1,5 dan 9 adalah komentar (comment)
# 2. Baris 2 Membuat variabel bernama a_1007 dan mengisinya dengan nilai 100 (tipe data int).
# 3. Baris 3 Mencetak teks, nilai dari a_1007 (100), dan tipe datanya yang diperiksa menggunakan fungsi type(a_1007) (menghasilkan <class 'int'>).
# 4. Baris 6 Membuat variabel b_2007 dan mengisinya dengan nilai 10.2345 (tipe data float).
# 5. Baris 7 Mencetak teks, nilai dari b_1007 (10.2345), dan tipe datanya via type(b_1007) (menghasilkan <class 'float'>).
# 6. Baris 10 Membuat variabel c_1007 dan mengisinya dengan nilai 100+3j (tipe data complex, di mana 100 adalah bagian riil dan 3j adalah bagian imajiner).
# 7. Baris 11 Mencetak teks, nilai dari c_1007 ((100+3j)), dan tipe datanya via type(c_1007) (menghasilkan <class 'complex'>).

# %% [markdown]
# ### 2.2.2 Program Operator Perbandingan "A_2611531007"

# %%
# Buat file dengan nama perbandingan_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input ()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator perbandingan dalam Python

angka1_1007 = int(input("Input Angka-1: "))
angka2_1007 = int(input("Input Angka-2: "))

# Lebih besar dari
hasil_1007 = angka1_1007 > angka2_1007
print("\nOperator lebih besar dari")
print("angka1_1007 > angka2_1007 =", hasil_1007)

# Lebih kecil dari
hasil_1007 = angka1_1007 < angka2_1007 
print("\nOperator lebih kecil dari")
print("angka1_1007 < angka2_1007 =", hasil_1007)

# Lebih besar dari atau sama dengan
hasil_1007 = angka1_1007 >= angka2_1007
print("\nOperator lebih besar dari atau sama dengan")
print("angka1_1007 >= angka2_1007 =", hasil_1007)

# Lebih kecil dari atau sama dengan
hasil_1007 = angka1_1007 <= angka2_1007
print("\nOperator Lebih kecil dari atau sama dengan")
print("angka1_1007 <= angka2_1007 =", hasil_1007)

# Sama dengan
hasil_1007 = angka1_1007 == angka2_1007
print("\nOperator sama dengan")
print("angka1_1007 == angka2_1007 =", hasil_1007)

# Tidak sama dengan
hasil_1007 = angka1_1007 != angka2_1007
print("\nOperator tidak saam dengan")
print("angka1_1007 != angka2_1007 =", hasil_1007)

# Tambahan perbandingan berantai dalam python
hasil_1007 = 0 < angka1_1007 < 100
print("\nPerbandingan berantai")
print("0 < angka1_1007 <100 =", hasil_1007)

hasil_1007 = 0 < angka2_1007 < 100
print("0 < angka2_1007 < 100 =", hasil_1007)
# Out:
# Operator lebih besar dari
# angka1_1007 > angka2_1007 = False
#
# Operator lebih kecil dari
# angka1_1007 < angka2_1007 = True
#
# Operator lebih besar dari atau sama dengan
# angka1_1007 >= angka2_1007 = False
#
# Operator Lebih kecil dari atau sama dengan
# angka1_1007 <= angka2_1007 = True
#
# Operator sama dengan
# angka1_1007 == angka2_1007 = False
#
# Operator tidak saam dengan
# angka1_1007 != angka2_1007 = True
#
# Perbandingan berantai
# 0 < angka1_1007 <100 = True
# 0 < angka2_1007 < 100 = True

# %% [markdown]
# Berikut penjelasan program :
#
# 1. Buat file dengan nama perbandingan_NIM.py — Komentar (diawali #, tidak dieksekusi), menjelaskan aturan penamaan file tugas.
#
# 2. Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234 — Komentar, menjelaskan aturan penamaan variabel harus diakhiri 4 digit terakhir NIM.
#
# 3. Program ini menggunakan fungsi input () — Komentar, menjelaskan bahwa program menerima input dari pengguna lewat fungsi input().
#
# 4. Nilai yang dimasukkan akan dikonversi menjadi tipe data integer — Komentar, menjelaskan bahwa input akan diubah ke tipe data integer (angka bulat).
#
# 5. Program operator perbandingan dalam Python — Komentar, judul/keterangan isi program.
#
# 6. angka1_1007 = int(input("Input Angka-1: ")) — Menampilkan teks Input Angka-1:, menunggu ketikan pengguna (hasil input() bertipe string), lalu int() mengonversinya menjadi integer, dan disimpan ke variabel angka1_1007.
#
# 7. angka2_1007 = int(input("Input Angka-2: ")) — Sama seperti baris 6, tetapi untuk angka kedua, disimpan ke variabel angka2_1007.
#
# 8. hasil_1007 = angka1_1007 > angka2_1007 — Membandingkan apakah angka1_1007 lebih besar dari angka2_1007; hasil boolean (True/False) disimpan ke hasil_1007.
#
# 9. print("\nOperator lebih besar dari") — Mencetak judul label; \n membuat baris kosong (spasi baris baru) sebelum teksnya.
#
# 10. print("angka1_1007 > angka2_1007 =", hasil_1007) — Mencetak teks perbandingan diikuti nilai hasil_1007 dari baris 8.
#
# 11. hasil_1007 = angka1_1007 < angka2_1007 — Membandingkan apakah angka1_1007 lebih kecil dari angka2_1007; nilai hasil_1007 ditimpa (assignment ulang) dengan hasil baru.
#
# 12. print("\nOperator lebih kecil dari") — Mencetak judul label untuk operator lebih kecil dari.
#
# 13. print("angka1_1007 < angka2_1007 =", hasil_1007) — Mencetak hasil perbandingan dari baris 11.
#
# 14. hasil_1007 = angka1_1007 >= angka2_1007 — Membandingkan apakah angka1_1007 lebih besar dari atau sama dengan angka2_1007.
#
# 15. print("\nOperator lebih besar dari atau sama dengan") — Mencetak judul label.
#
# 16. print("angka1_1007 >= angka2_1007 =", hasil_1007) — Mencetak hasil perbandingan dari baris 14.
#
# 17. hasil_1007 = angka1_1007 <= angka2_1007 — Membandingkan apakah angka1_1007 lebih kecil dari atau sama dengan angka2_1007.
#
# 18. print("\nOperator Lebih kecil dari atau sama dengan") — Mencetak judul label.
#
# 19. print("angka1_1007 <= angka2_1007 =", hasil_1007) — Mencetak hasil perbandingan dari baris 17.
#
# 20. hasil_1007 = angka1_1007 == angka2_1007 — Membandingkan apakah nilai angka1_1007 sama dengan angka2_1007 (perbandingan nilai, bukan penugasan seperti = tunggal).
#
# 21. print("\nOperator sama dengan") — Mencetak judul label.
#
# 22. print("angka1_1007 == angka2_1007 =", hasil_1007) — Mencetak hasil perbandingan dari baris 20.
#
# 23. hasil_1007 = angka1_1007 != angka2_1007 — Membandingkan apakah nilai angka1_1007 tidak sama dengan angka2_1007.
#
# 24. print("\nOperator tidak saam dengan") — Mencetak judul label (ada typo: "saam" seharusnya "sama").
#
# 25. print("angka1_1007 != angka2_1007 =", hasil_1007) — Mencetak hasil perbandingan dari baris 23.
#
# 26. hasil_1007 = 0 < angka1_1007 < 100 — Perbandingan berantai (chained comparison), setara dengan (0 < angka1_1007) and (angka1_1007 < 100); bernilai True hanya jika angka1_1007 berada di antara 0 dan 100 (tidak termasuk 0 dan 100 itu sendiri).
#
# 27. print("\nPerbandingan berantai") — Mencetak judul label.
#
# 28. print("0 < angka1_1007 <100 =", hasil_1007) — Mencetak hasil perbandingan berantai dari baris 26.
#
# 29. hasil_1007 = 0 < angka2_1007 < 100 — Perbandingan berantai yang sama, tetapi untuk angka2_1007.
#
# 30. print("0 < angka2_1007 < 100 =", hasil_1007) — Mencetak hasil perbandingan berantai dari baris 29.

# %% [markdown]
# ### 2.2.3 Program Operator Logika "A_2611531007"

# %%
# Buat file dengan nama logika_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: a1_1234
# Program ini menggunakan fungsi input ()
# Program operator logika dalam Python

# Memasukkan nilai boolean
# Input tidak peka terhdap huruf besar dan kecil
a1_1007 = input("Input nilai Boolean-1 (true/false): ").strip().lower() == "true"
a2_1007 = input("Input nilai Boolean-1 (true/false): ").strip().lower() == "true"

print("\nA1_1007 =", a1_1007)
print("A2_1007 =", a2_1007)

# Konjungsi: bernilai True dika keduanya True
hasil_1007 = a1_1007 and a2_1007
print("\nKonjungsi (AND)")
print("A1 and A2 =", hasil_1007)

# Disjungsi: bernilai True jika salah satunya True
hasil_1007 = a1_1007 or a2_1007
print("\nDisjungsi (OR)")
print("A1_1007 or A2_1007 =", hasil_1007)

# Negasi A2: membalik nilai A2
hasil_1007 = not a2_1007
print("\nNegasi A2_1007 (NOT)")
print("not A2_1007 =", hasil_1007)

# XOR: bernilai True jika kedua nilai berbeda
hasil_1007 = a1_1007 != a2_1007
print("\nDisjungsi Eksklusif (XOR)")
print("A1_1007 XOR A2_1007 =", hasil_1007)
# Out:
# A1_1007 = True
# A2_1007 = False
#
# Konjungsi (AND)
# A1 and A2 = False
#
# Disjungsi (OR)
# A1_1007 or A2_1007 = True
#
# Negasi A2_1007 (NOT)
# not A2_1007 = True
#
# Disjungsi Eksklusif (XOR)
# A1_1007 XOR A2_1007 = True

# %% [markdown]
# Berikut penjelasan program :
#
# 1. Buat file dengan nama logika_NIM.py — Komentar (diawali #, tidak dieksekusi), menjelaskan aturan penamaan file tugas.
#
# 2. Nama variabel ditambah 4 digit nim terakhir contoh: a1_1234 — Komentar, menjelaskan aturan penamaan variabel harus diakhiri 4 digit terakhir NIM.
#
# 3. Program ini menggunakan fungsi input () — Komentar, menjelaskan bahwa program menerima input dari pengguna lewat fungsi input().
#
# 4. Program operator logika dalam Python — Komentar, judul/keterangan isi program.
#
# 5. Memasukkan nilai boolean — Komentar, menjelaskan bagian berikutnya berkaitan dengan input nilai boolean.
#
# 6. Input tidak peka terhdap huruf besar dan kecil — Komentar, menjelaskan bahwa input "true"/"True"/"TRUE" akan tetap dianggap sama (case-insensitive).
#
# 7. a1_1007 = input("Input nilai Boolean-1 (true/false): ").strip().lower() == "true" — Menampilkan teks permintaan input, hasil ketikan pengguna (bertipe string) kemudian diproses tiga tahap: strip() menghapus spasi di awal/akhir teks, lower() mengubah semua huruf jadi huruf kecil, lalu dibandingkan dengan == "true". Hasil perbandingan (True/False) disimpan ke variabel a1_1007.
#
# 8. a2_1007 = input("Input nilai Boolean-1 (true/false): ").strip().lower() == "true" — Pola sama seperti baris 7, tetapi untuk nilai boolean kedua, disimpan ke variabel a2_1007. (Catatan: label teksnya masih tertulis "Boolean-1", seharusnya "Boolean-2".)
#
# 9. print("\nA1_1007 =", a1_1007) — Mencetak baris kosong lalu nilai a1_1007 yang sudah dikonversi jadi boolean.
#
# 10. print("A2_1007 =", a2_1007) — Mencetak nilai a2_1007 yang sudah dikonversi jadi boolean.
#
# 11. Konjungsi: bernilai True dika keduanya True — Komentar, menjelaskan operator AND (ada typo: "dika" seharusnya "jika").
#
# 12. hasil_1007 = a1_1007 and a2_1007 — Operator and menghasilkan True hanya jika a1_1007 dan a2_1007 dua-duanya bernilai True; hasil disimpan ke hasil_1007.
#
# 13. print("\nKonjungsi (AND)") — Mencetak judul label untuk operator AND.
#
# 14. print("A1 and A2 =", hasil_1007) — Mencetak hasil operasi AND dari baris 12.
#
# 15. Disjungsi: bernilai True jika salah satunya True — Komentar, menjelaskan operator OR.
#
# 16. hasil_1007 = a1_1007 or a2_1007 — Operator or menghasilkan True jika salah satu (atau keduanya) dari a1_1007 dan a2_1007 bernilai True; nilai hasil_1007 ditimpa dengan hasil baru.
#
# 17. print("\nDisjungsi (OR)") — Mencetak judul label untuk operator OR.
#
# 18. print("A1_1007 or A2_1007 =", hasil_1007) — Mencetak hasil operasi OR dari baris 16.
#
# 19. Negasi A2: membalik nilai A2 — Komentar, menjelaskan operator NOT.
#
# 20. hasil_1007 = not a2_1007 — Operator not membalik nilai boolean a2_1007 (True menjadi False, atau sebaliknya); hasil disimpan ke hasil_1007.
#
# 21. print("\nNegasi A2_1007 (NOT)") — Mencetak judul label untuk operator NOT.
#
# 22. print("not A2_1007 =", hasil_1007) — Mencetak hasil operasi NOT dari baris 20.
#
# 23. XOR: bernilai True jika kedua nilai berbeda — Komentar, menjelaskan logika XOR (exclusive or).
#
# 24. hasil_1007 = a1_1007 != a2_1007 — Karena Python tidak punya operator khusus untuk XOR pada boolean, operator != (tidak sama dengan) dimanfaatkan sebagai XOR: hasilnya True hanya jika nilai a1_1007 dan a2_1007 berbeda (satu True satu False).
#
# 25. print("\nDisjungsi Eksklusif (XOR)") — Mencetak judul label untuk operasi XOR.
#
# 26. print("A1_1007 XOR A2_1007 =", hasil_1007) — Mencetak hasil operasi XOR dari baris 24.

# %% [markdown]
# ### 2.2.4 Program Operator Assignment "A_2611531007"

# %%
# Buat file dengan nama assignment_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input ()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator assignmet dalam python

angka1_1007 = int(input("Input angka-1: "))
angka2_1007 = int(input("Input angka-2: "))

print("\nNilai awal angka1_1007 =", angka1_1007)
print("Nilai angka2_1007 =", angka1_1007)

# Assignment penambahan
hasil_1007 = angka1_1007
hasil_1007 += angka2_1007
print("\nAssignment penambahan (+=)")
print("Hasil =", hasil_1007)

# Assignment pengurangan
hasil_1007 = angka1_1007
hasil_1007 -= angka2_1007
print("\nAssignment penguranngan (-=)")
print(("Hasil =", hasil_1007))

# Assignment perkalian 
hasil_1007 = angka1_1007
hasil_1007 *= angka2_1007
print("\nAssignment perkalian (*=)")
print("Hasil =", hasil_1007)

# Assignmnet pembagian, pembagian bulat, dan sisa bagi
if angka2_1007 != 0:
    hasil_1007 = angka1_1007
    hasil_1007 /= angka2_1007
    print("\nAssignment pembagian bulat (/=)")
    print("Hasil =", hasil_1007)
    
    #Operator tambahan
    hasil_1007 = angka1_1007
    hasil_1007 //= angka2_1007
    print("\nAssignment pembagian bulau (//=)")
    print("Hasil =", hasil_1007)
    hasil_1007 = angka1_1007
    hasil_1007 %= angka2_1007
    print("\nAssignment sisa bagi (%=)")
    print("Hasil =", hasil_1007)
else:
    print("\nPembagian tidak dapat dilakukan")
    print("Angka kedau tidak bole bernilai 0")

# Operator tambahan assignment perpangkatan
hasil = angka1_1007
hasil_1007 **= angka2_1007
print("\nAssignment perpangkatan (**=)")
print("Hasil =", hasil_1007)
# Out:
# Nilai awal angka1_1007 = 6
# Nilai angka2_1007 = 6
#
# Assignment penambahan (+=)
# Hasil = 15
#
# Assignment penguranngan (-=)
# ('Hasil =', -3)
#
# Assignment perkalian (*=)
# Hasil = 54
#
# Assignment pembagian bulat (/=)
# Hasil = 0.6666666666666666
#
# Assignment pembagian bulau (//=)
# Hasil = 0
#
# Assignment sisa bagi (%=)
# Hasil = 6
#
# Assignment perpangkatan (**=)
# Hasil = 10077696

# %% [markdown]
# Berikut penjelasan program :
#
# 1. Buat file dengan nama assignment_NIM.py — Komentar (diawali #, tidak dieksekusi), menjelaskan aturan penamaan file tugas.
#
# 2. Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234 — Komentar, menjelaskan aturan penamaan variabel harus diakhiri 4 digit terakhir NIM.
#
# 3. Program ini menggunakan fungsi input () — Komentar, menjelaskan bahwa program menerima input dari pengguna lewat fungsi input().
#
# 4. Nilai yang dimasukkan akan dikonversi menjadi tipe data integer — Komentar, menjelaskan bahwa input akan diubah ke tipe data integer.
#
# 5. Program operator assignmet dalam python — Komentar, judul/keterangan isi program (ada typo: "assignmet" seharusnya "assignment").
#
# 6. angka1_1007 = int(input("Input angka-1: ")) — Menampilkan teks permintaan input, hasil ketikan pengguna (string) dikonversi int() menjadi integer, disimpan ke variabel angka1_1007.
#
# 7. angka2_1007 = int(input("Input angka-2: ")) — Sama seperti baris 6, tetapi untuk angka kedua, disimpan ke variabel angka2_1007.
#
# 8. print("\nNilai awal angka1_1007 =", angka1_1007) — Mencetak baris kosong lalu nilai awal angka1_1007.
#
# 9. print("Nilai angka2_1007 =", angka1_1007) — Mencetak label "Nilai angka2_1007" tetapi isinya menampilkan angka1_1007, bukan angka2_1007 — ini kekeliruan penulisan, seharusnya variabel yang dicetak adalah angka2_1007.
#
# 10. Assignment penambahan — Komentar, menandai bagian penjelasan operator +=.
#
# 11. hasil_1007 = angka1_1007 — Menyalin nilai angka1_1007 ke variabel hasil_1007 sebagai nilai awal sebelum dioperasikan.
#
# 12. hasil_1007 += angka2_1007 — Augmented assignment penambahan, setara dengan hasil_1007 = hasil_1007 + angka2_1007; menambahkan nilai angka2_1007 ke hasil_1007 lalu menyimpannya kembali ke variabel yang sama.
#
# 13. print("\nAssignment penambahan (+=)") — Mencetak judul label untuk operator +=.
#
# 14. print("Hasil =", hasil_1007) — Mencetak hasil dari operasi += pada baris 12.
#
# 15. Assignment pengurangan — Komentar, menandai bagian penjelasan operator -=.
#
# 16. hasil_1007 = angka1_1007 — Mengatur ulang nilai hasil_1007 kembali ke angka1_1007 sebagai nilai awal (reset sebelum operasi baru).
#
# 17. hasil_1007 -= angka2_1007 — Augmented assignment pengurangan, setara dengan hasil_1007 = hasil_1007 - angka2_1007.
#
# 18. print("\nAssignment penguranngan (-=)") — Mencetak judul label untuk operator -= (ada typo: "penguranngan" seharusnya "pengurangan").
#
# 19. print(("Hasil =", hasil_1007)) — Mencetak hasil operasi -= dari baris 17; tanda kurung ganda di sini menyebabkan Python mencetak sebuah tuple (teks dan nilai digabung dalam satu kurung), bukan dua argumen terpisah seperti print biasa — hasil tampilannya tetap benar tetapi formatnya akan muncul dengan tanda kurung dan koma, sedikit berbeda dari baris print lain di program ini.
#
# 20. Assignment perkalian — Komentar, menandai bagian penjelasan operator *=.
#
# 21. hasil_1007 = angka1_1007 — Reset nilai hasil_1007 ke angka1_1007 sebagai nilai awal.
#
# 22. hasil_1007 *= angka2_1007 — Augmented assignment perkalian, setara dengan hasil_1007 = hasil_1007 * angka2_1007.
#
# 23. print("\nAssignment perkalian (*=)") — Mencetak judul label untuk operator *=.
#
# 24. print("Hasil =", hasil_1007) — Mencetak hasil operasi *= dari baris 22.
#
# 25. Assignmnet pembagian, pembagian bulat, dan sisa bagi — Komentar, menandai bagian yang menangani tiga jenis operator pembagian (ada typo: "Assignmnet" seharusnya "Assignment").
#
# 26. if angka2_1007 != 0: — Percabangan kondisi, memeriksa apakah angka2_1007 tidak sama dengan 0; bagian pembagian hanya dijalankan jika kondisi ini True, untuk mencegah error pembagian dengan nol (ZeroDivisionError).
#
# 27. hasil_1007 = angka1_1007 — Reset nilai hasil_1007 ke angka1_1007 sebagai nilai awal, dijalankan di dalam blok if.
#
# 28. hasil_1007 /= angka2_1007 — Augmented assignment pembagian biasa, setara dengan hasil_1007 = hasil_1007 / angka2_1007; hasilnya selalu bertipe float (pecahan), meski hasil bagi bulat sekalipun.
#
# 29. print("\nAssignment pembagian bulat (/=)") — Mencetak judul label; label ini kurang tepat karena /= sebenarnya adalah pembagian biasa (hasil pecahan), bukan pembagian bulat — pembagian bulat yang sebenarnya ada pada operator //= di bawah.
#
# 30. print("Hasil =", hasil_1007) — Mencetak hasil operasi /= dari baris 28.
#
# 31. Operator tambahan — Komentar, menandai penjelasan tambahan berupa dua operator assignment lain.
#
# 32. hasil_1007 = angka1_1007 — Reset nilai hasil_1007 ke angka1_1007 sebagai nilai awal.
#
# 33. hasil_1007 //= angka2_1007 — Augmented assignment pembagian bulat (floor division), setara dengan hasil_1007 = hasil_1007 // angka2_1007; hasilnya berupa bilangan bulat yang dibulatkan ke bawah.
#
# 34. print("\nAssignment pembagian bulau (//=)") — Mencetak judul label untuk operator //= (ada typo: "bulau" seharusnya "bulat").
#
# 35. print("Hasil =", hasil_1007) — Mencetak hasil operasi //= dari baris 33.
#
# 36. hasil_1007 = angka1_1007 — Reset nilai hasil_1007 ke angka1_1007 sebagai nilai awal.
#
# 37. hasil_1007 %= angka2_1007 — Augmented assignment modulus (sisa bagi), setara dengan hasil_1007 = hasil_1007 % angka2_1007.
#
# 38. print("\nAssignment sisa bagi (%=)") — Mencetak judul label untuk operator %=.
#
# 39. print("Hasil =", hasil_1007) — Mencetak hasil operasi %= dari baris 37.
#
# 40. else: — Bagian yang dijalankan jika kondisi if pada baris 26 bernilai False, yaitu ketika angka2_1007 sama dengan 0.
#
# 41. print("\nPembagian tidak dapat dilakukan") — Mencetak pesan bahwa pembagian tidak bisa dilakukan (karena pembagi bernilai 0).
#
# 42. print("Angka kedau tidak bole bernilai 0") — Mencetak pesan lanjutan penjelas alasan (ada dua typo: "kedau" seharusnya "kedua", dan "bole" seharusnya "boleh").
#
# 43. Operator tambahan assignment perpangkatan — Komentar, menandai bagian terakhir untuk operator **=. Baris ini berada di luar blok if-else, sehingga selalu dijalankan terlepas dari nilai angka2_1007.
#
# 44. hasil = angka1_1007 — Membuat variabel baru bernama hasil (tanpa akhiran _1007) dan mengisinya dengan nilai angka1_1007 — ini adalah kekeliruan penulisan, karena seharusnya variabel ini bernama hasil_1007 sesuai aturan penamaan variabel pada tugas, dan variabel ini sebenarnya tidak terpakai di baris berikutnya.
#
# 45. hasil_1007 **= angka2_1007 — Augmented assignment perpangkatan, setara dengan hasil_1007 = hasil_1007 ** angka2_1007; namun karena hasil_1007 di sini masih menyimpan nilai sisa bagi dari operasi %= sebelumnya (bukan direset ke angka1_1007 seperti pola operator lain di atas, akibat kekeliruan pada baris 44), maka hasil perpangkatan yang dicetak bukan angka1_1007 pangkat angka2_1007, melainkan sisa-bagi-dari-langkah-sebelumnya pangkat angka2_1007.
#
# 46. print("\nAssignment perpangkatan (**=)") — Mencetak judul label untuk operator **=.
#
# 47. print("Hasil =", hasil_1007) — Mencetak hasil operasi **= dari baris 45, yang nilainya terpengaruh oleh kekeliruan pada baris 44 seperti dijelaskan di atas.

# %% [markdown]
# ### 2.2.5 Program Operator Lainnya "A_2611531007"

# %%
# Buat file dengan nama lainnya_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input ()
# Program operator keanggotaan dan identitas

print("================================")
print("1. OPERATOR KEANGGOTAAN")
print("================================")

# Input beberapa data yang dipisahkan dengan koma
input_data_1007 = input("Masukkan beberapa angka, pisahkan dengan koma: ")

# Mengubah input menjadi list integer
data_1007 = [int(angka.strip()) for angka in input_data_1007.split(",")]

nilai_dicari_1007 = int(input("Masukkan angka yang ingin dicari: "))

# Operator in
hasil_1007 = nilai_dicari_1007 in data_1007
print("\nOperator keanggotan IN")
print(nilai_dicari_1007, "in", data_1007, "=", hasil_1007)

# Operator not in
hasil_1007 = nilai_dicari_1007 not in data_1007
print("\nOperator Keanggotaan NOT IN")
print(nilai_dicari_1007, "not in", data_1007, "=", hasil_1007)

print("\n========================")
print("2. OPERATOR IDENTITAS")
print("========================")

# objek menggunakan list dari input pengguna
objek1_1007 = data_1007

# objek merujuk pada objek yang sama dengan objek1_1007
objek2_1007 = objek1_1007

# objek memiliki isi sama, tetapi merupakan objek baru
objek3_1007 = data_1007.copy()

print("objek1_1007 =", objek1_1007)
print("objek2_1007 =", objek2_1007)
print("objek3_1007 =", objek3_1007)

# Operator is
hasil_1007 = objek1_1007 is objek2_1007
print("\nOperator Identitas IS")
print("objek1_1007 is objek2_1007 =", hasil_1007)

# Operator is not
hasil_1007 = objek1_1007 is not objek3_1007
print("\nOperator Identitas IS NOT")
print("objek1_1007 is not objek3_1007 =", hasil_1007)

# Membandingkan identitas dan nilai
print("\nPerbandingan identitsa dan nilai")
print("obejk1_1007 is objek3_1007 =", objek1_1007 is objek3_1007)
print("objek1_1007 == obje3_1007 =", objek1_1007 == objek3_1007)
# Out:
# ...
# 1. OPERATOR KEANGGOTAAN
# ...
#
# Operator keanggotan IN
# 4 in [1, 8, 5, 9, 22, 7, 19, 44] = False
#
# Operator Keanggotaan NOT IN
# 4 not in [1, 8, 5, 9, 22, 7, 19, 44] = True
#
# ...
# 2. OPERATOR IDENTITAS
# ...
# objek1_1007 = [1, 8, 5, 9, 22, 7, 19, 44]
# objek2_1007 = [1, 8, 5, 9, 22, 7, 19, 44]
# objek3_1007 = [1, 8, 5, 9, 22, 7, 19, 44]
#
# Operator Identitas IS
# objek1_1007 is objek2_1007 = True
#
# Operator Identitas IS NOT
# objek1_1007 is not objek3_1007 = True
#
# Perbandingan identitsa dan nilai
# obejk1_1007 is objek3_1007 = False
# objek1_1007 == obje3_1007 = True

# %% [markdown]
# Berikut penjelasan program :
#
# 1. Buat file dengan nama lainnya_NIM.py — Komentar (diawali #, tidak dieksekusi), menjelaskan aturan penamaan file tugas.
#
# 2. Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234 — Komentar, menjelaskan aturan penamaan variabel harus diakhiri 4 digit terakhir NIM.
#
# 3. Program ini menggunakan fungsi input () — Komentar, menjelaskan bahwa program menerima input dari pengguna lewat fungsi input().
#
# 4. Program operator keanggotaan dan identitas — Komentar, judul/keterangan isi program.
#
# 5. print("================================") — Mencetak garis pembatas sebagai pemisah visual antar bagian program.
#
# 6. print("1. OPERATOR KEANGGOTAAN") — Mencetak judul bagian pertama, yaitu operator keanggotaan.
#
# 7. print("================================") — Mencetak garis pembatas penutup judul bagian pertama.
#
# 8. Input beberapa data yang dipisahkan dengan koma — Komentar, menjelaskan bahwa pengguna akan memasukkan beberapa angka sekaligus dalam satu baris, dipisahkan tanda koma.
#
# 9. input_data_1007 = input("Masukkan beberapa angka, pisahkan dengan koma: ") — Menampilkan teks permintaan input, hasil ketikan pengguna (misalnya "1, 2, 3") disimpan sebagai satu string utuh ke variabel input_data_1007.
#
# 10. Mengubah input menjadi list integer — Komentar, menjelaskan bahwa string input akan diubah menjadi daftar (list) berisi angka.
#
# 11. data_1007 = [int(angka.strip()) for angka in input_data_1007.split(",")] — Sebuah list comprehension: split(",") memecah string input_data_1007 menjadi beberapa bagian berdasarkan tanda koma, lalu untuk tiap bagian (angka), strip() menghapus spasi di sekitarnya dan int() mengonversinya menjadi integer; seluruh hasil konversi dikumpulkan menjadi satu list dan disimpan ke variabel data_1007.
#
# 12. nilai_dicari_1007 = int(input("Masukkan angka yang ingin dicari: ")) — Menampilkan teks permintaan input, hasil ketikan pengguna dikonversi int() menjadi integer, disimpan ke variabel nilai_dicari_1007.
#
# 13. Operator in — Komentar, menandai bagian penjelasan operator in.
#
# 14. hasil_1007 = nilai_dicari_1007 in data_1007 — Operator in memeriksa apakah nilai nilai_dicari_1007 terdapat di dalam list data_1007; hasilnya boolean (True/False) disimpan ke hasil_1007.
#
# 15. print("\nOperator keanggotan IN") — Mencetak baris kosong lalu judul label untuk operator IN.
#
# 16. print(nilai_dicari_1007, "in", data_1007, "=", hasil_1007) — Mencetak nilai yang dicari, kata "in", isi list data_1007, dan hasil pemeriksaan dari baris 14.
#
# 17. Operator not in — Komentar, menandai bagian penjelasan operator not in.
#
# 18. hasil_1007 = nilai_dicari_1007 not in data_1007 — Operator not in memeriksa kebalikannya, yaitu apakah nilai_dicari_1007 tidak terdapat di dalam data_1007; nilai hasil_1007 ditimpa dengan hasil baru.
#
# 19. print("\nOperator Keanggotaan NOT IN") — Mencetak judul label untuk operator NOT IN.
#
# 20. print(nilai_dicari_1007, "not in", data_1007, "=", hasil_1007) — Mencetak hasil pemeriksaan dari baris 18.
#
# 21. print("\n========================") — Mencetak baris kosong lalu garis pembatas untuk mengawali bagian kedua.
#
# 22. print("2. OPERATOR IDENTITAS") — Mencetak judul bagian kedua, yaitu operator identitas.
#
# 23. print("========================") — Mencetak garis pembatas penutup judul bagian kedua.
#
# 24. objek menggunakan list dari input pengguna — Komentar, menjelaskan bahwa objek-objek berikut dibuat berdasarkan data_1007 dari input pengguna.
#
# 25. objek1_1007 = data_1007 — Membuat variabel objek1_1007 yang menunjuk ke objek list yang sama dengan data_1007 (bukan salinan baru, hanya nama lain untuk objek yang sama).
#
# 26. objek merujuk pada objek yang sama dengan objek1_1007 — Komentar, menjelaskan baris berikutnya.
#
# 27. objek2_1007 = objek1_1007 — Membuat variabel objek2_1007 yang juga menunjuk ke objek yang sama persis dengan objek1_1007 (dan otomatis sama dengan data_1007).
#
# 28. objek memiliki isi sama, tetapi merupakan objek baru — Komentar, menjelaskan baris berikutnya.
#
# 29. objek3_1007 = data_1007.copy() — Metode copy() membuat salinan baru dari list data_1007 ke lokasi memori yang berbeda; objek3_1007 memiliki isi yang identik dengan data_1007, tetapi merupakan objek yang terpisah di memori.
#
# 30. print("objek1_1007 =", objek1_1007) — Mencetak isi objek1_1007.
#
# 31. print("objek2_1007 =", objek2_1007) — Mencetak isi objek2_1007.
#
# 32. print("objek3_1007 =", objek3_1007) — Mencetak isi objek3_1007.
#
# 33. Operator is — Komentar, menandai bagian penjelasan operator is.
#
# 34. hasil_1007 = objek1_1007 is objek2_1007 — Operator is memeriksa apakah objek1_1007 dan objek2_1007 menunjuk ke objek yang sama persis di memori; karena objek2_1007 dibuat dari objek1_1007 langsung (baris 27), hasilnya True.
#
# 35. print("\nOperator Identitas IS") — Mencetak judul label untuk operator IS.
#
# 36. print("objek1_1007 is objek2_1007 =", hasil_1007) — Mencetak hasil pemeriksaan dari baris 34.
#
# 37. Operator is not — Komentar, menandai bagian penjelasan operator is not.
#
# 38. hasil_1007 = objek1_1007 is not objek3_1007 — Operator is not memeriksa apakah objek1_1007 dan objek3_1007 bukan objek yang sama di memori; karena objek3_1007 dibuat dengan copy() (baris 29) sehingga menjadi objek terpisah, hasilnya True meskipun isinya sama.
#
# 39. print("\nOperator Identitas IS NOT") — Mencetak judul label untuk operator IS NOT.
#
# 40. print("objek1_1007 is not objek3_1007 =", hasil_1007) — Mencetak hasil pemeriksaan dari baris 38.
#
# 41. Membandingkan identitas dan nilai — Komentar, menandai bagian penutup yang membandingkan langsung operator is dan ==.
#
# 42. print("\nPerbandingan identitsa dan nilai") — Mencetak baris kosong lalu judul label bagian perbandingan (ada typo: "identitsa" seharusnya "identitas").
#
# 43. print("obejk1_1007 is objek3_1007 =", objek1_1007 is objek3_1007) — Mencetak hasil objek1_1007 is objek3_1007 secara langsung (dihitung saat print dipanggil, tanpa disimpan ke variabel hasil_1007); bernilai False karena keduanya objek berbeda di memori meski isinya sama (ada typo pada teks label: "obejk1_1007" seharusnya "objek1_1007").
#
# 44. print("objek1_1007 == obje3_1007 =", objek1_1007 == objek3_1007) — Mencetak hasil objek1_1007 == objek3_1007; bernilai True karena == membandingkan isi/nilai, bukan identitas objek, dan isi kedua list tersebut sama persis (ada typo pada teks label: "obje3_1007" seharusnya "objek3_1007").

# %% [markdown]
# ### 2.2.6 Program Operator Bitwise "A_2611531007"

# %%
# Buat file dengan nama bitwise_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()

print("================================")
print("3. OPERATOR BITWISE")
print("================================")

angka1_1007 = int(input("Masukkan angka bitwise-1: "))
angka2_1007 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner")
print("angka1_1007 =", angka1_1007, "| biner =", bin(angka1_1007))
print("angka2_1007 =", angka2_1007, "| biner =", bin(angka2_1007))

# Bitwise AND
hasil_1007 = angka1_1007 & angka2_1007
print("\nBitwise AND (&)")
print(angka1_1007, "&", angka2_1007)
print("Biner hasik (8 bit) =", format(hasil_1007, "08b"))

# Bitwise OR
hasil_1007 = angka1_1007 |angka2_1007
print("\nBitwise OR (|)")
print(angka1_1007, "|", angka2_1007, "=", hasil_1007)
print("Biner hasil =", bin(hasil_1007))
print("Biner hasil (8 bit) =", format(hasil_1007, "08b"))

# Bitwise XOR
hasil_1007 = angka1_1007 ^ angka1_1007
print("\nBitwise XOR (^)")
print(angka1_1007)
# Out:
# ...
# 3. OPERATOR BITWISE
# ...
#
# Angka dalam bentuk desimal dan biner
# angka1_1007 = 4 | biner = 0b100
# angka2_1007 = 1 | biner = 0b1
#
# Bitwise AND (&)
# 4 & 1
# Biner hasik (8 bit) = 00000000
#
# Bitwise OR (|)
# 4 | 1 = 5
# Biner hasil = 0b101
# Biner hasil (8 bit) = 00000101
#
# Bitwise XOR (^)
# 4

# %% [markdown]
# Berikut penjelasan program :
#
# 1. Buat file dengan nama bitwise_NIM.py — Komentar (diawali #, tidak dieksekusi), menjelaskan aturan penamaan file tugas.
#
# 2. Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234 — Komentar, menjelaskan aturan penamaan variabel harus diakhiri 4 digit terakhir NIM.
#
# 3. Program ini menggunakan fungsi input() — Komentar, menjelaskan bahwa program menerima input dari pengguna lewat fungsi input().
#
# 4. print("================================") — Mencetak garis pembatas sebagai pemisah visual.
#
# 5. print("3. OPERATOR BITWISE") — Mencetak judul bagian program, yaitu operator bitwise.
#
# 6. print("================================") — Mencetak garis pembatas penutup judul.
#
# 7. angka1_1007 = int(input("Masukkan angka bitwise-1: ")) — Menampilkan teks permintaan input, hasil ketikan pengguna (string) dikonversi int() menjadi integer, disimpan ke variabel angka1_1007.
#
# 8. angka2_1007 = int(input("Masukkan angka bitwise-2: ")) — Sama seperti baris 7, tetapi untuk angka kedua, disimpan ke variabel angka2_1007.
#
# 9. print("\nAngka dalam bentuk desimal dan biner") — Mencetak baris kosong lalu judul label bagian penampil bentuk desimal dan biner.
#
# 10. print("angka1_1007 =", angka1_1007, "| biner =", bin(angka1_1007)) — Mencetak nilai desimal angka1_1007, lalu fungsi bin() mengubahnya menjadi representasi biner (diawali "0b").
#
# 11. print("angka2_1007 =", angka2_1007, "| biner =", bin(angka2_1007)) — Sama seperti baris 10, tetapi untuk angka2_1007.
#
# 12. Bitwise AND — Komentar, menandai bagian penjelasan operator AND.
#
# 13. hasil_1007 = angka1_1007 & angka2_1007 — Operator & (AND) membandingkan tiap bit kedua angka; hasil bit bernilai 1 hanya jika kedua bit pada posisi yang sama bernilai 1. Hasilnya (dalam desimal) disimpan ke variabel hasil_1007.
#
# 14. print("\nBitwise AND (&)") — Mencetak judul label untuk operator AND.
#
# 15. print(angka1_1007, "&", angka2_1007) — Mencetak kedua angka dan simbol operator &, tetapi baris ini **tidak mencetak hasilnya** (hasil_1007 dari baris 13 tidak dimasukkan ke print ini) — ini kemungkinan kekurangan pada program, karena hasilnya baru bisa dilihat lewat representasi biner di baris berikutnya.
#
# 16. print("Biner hasik (8 bit) =", format(hasil_1007, "08b")) — Fungsi format(hasil_1007, "08b") mengubah hasil_1007 menjadi teks biner sepanjang minimal 8 digit (ditambah angka 0 di depan jika kurang), lalu dicetak (ada typo pada label: "hasik" seharusnya "hasil").
#
# 17. Bitwise OR — Komentar, menandai bagian penjelasan operator OR.
#
# 18. hasil_1007 = angka1_1007 |angka2_1007 — Operator | (OR) membandingkan tiap bit kedua angka; hasil bit bernilai 1 jika salah satu atau kedua bit bernilai 1. Hasilnya menimpa nilai hasil_1007 sebelumnya. (Catatan kecil: penulisan `|angka2_1007` tanpa spasi tetap valid secara sintaks di Python, hanya kurang rapi secara gaya penulisan.)
#
# 19. print("\nBitwise OR (|)") — Mencetak judul label untuk operator OR.
#
# 20. print(angka1_1007, "|", angka2_1007, "=", hasil_1007) — Mencetak kedua angka, simbol operator |, dan hasil (dalam bentuk desimal) dari baris 18.
#
# 21. print("Biner hasil =", bin(hasil_1007)) — Mencetak hasil OR dalam bentuk biner menggunakan bin().
#
# 22. print("Biner hasil (8 bit) =", format(hasil_1007, "08b")) — Mencetak hasil OR dalam bentuk biner 8 digit menggunakan format().
#
# 23. Bitwise XOR — Komentar, menandai bagian penjelasan operator XOR.
#
# 24. hasil_1007 = angka1_1007 ^ angka1_1007 — Operator ^ (XOR) seharusnya membandingkan angka1_1007 dengan angka2_1007 (hasil bit bernilai 1 jika kedua bit berbeda), tetapi pada baris ini yang dioperasikan adalah angka1_1007 ^ angka1_1007 (angka1 dengan dirinya sendiri) — ini kemungkinan besar **kesalahan penulisan/typo**, seharusnya operand kedua adalah angka2_1007. Karena XOR antara angka dengan dirinya sendiri selalu menghasilkan 0, hasil_1007 pada baris ini akan selalu bernilai 0, berapa pun nilai angka1_1007-nya.
#
# 25. print(angka1_1007) — Mencetak nilai angka1_1007 saja; program terpotong di sini, belum mencetak label judul XOR maupun hasil operasi XOR dari baris 24 (dan juga belum menampilkan bagian operator bitwise lain seperti NOT `~` atau shift `<<`/`>>` yang biasanya diminta pada studi kasus serupa).

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="images/foto_soal3.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %%
print("===== SISTEM TRANSAKSI TOKO =====\n")

# 1. INPUT DATA PELANGGAN DAN TRANSAKSI
nama_1007 = input("Masukkan Nama Pelanggan : ")
status_1007 = input("Masukkan Status Pelanggan (member/nonmember) : ")
total_1007 = float(input("Masukkan Total Belanja : "))
jumlah_1007 = int(input("Masukkan Jumlah Barang : "))
promo_1007 = input("Masukkan Kode Promo : ")

print("\n===== DATA TRANSAKSI =====")
print(f"Nama Pelanggan       : {nama_1007}")
print(f"Status Pelanggan     : {status_1007}")
print(f"Total Belanja        : Rp{total_1007:}")
print(f"Jumlah Barang        : {jumlah_1007}")
print(f"Kode Promo           : {promo_1007}")

# Daftar kode promo yang tersedia di toko
daftar_promo_1007 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]

# 2. OPERATOR PERBANDINGAN
syarat_belanja_1007 = total_1007 >= 200000          
syarat_barang_1007 = jumlah_1007 >= 3                
is_member_1007 = status_1007 == "member"             

# 3. OPERATOR KEANGGOTAAN (in / not in)
promo_tersedia_1007 = promo_1007 in daftar_promo_1007
promo_tidak_tersedia_1007 = promo_1007 not in daftar_promo_1007


# 4. OPERATOR LOGIKA (and, or, not)
diskon_member_1007 = is_member_1007 and syarat_belanja_1007
dapat_promo_1007 = promo_tersedia_1007 and (syarat_belanja_1007 or syarat_barang_1007)
bukan_member_1007 = not is_member_1007

print("\n===== HASIL VALIDASI =====")
print(f"Belanja >= Rp200000        : {syarat_belanja_1007}")
print(f"Jumlah Barang >= 3         : {syarat_barang_1007}")
print(f"Status Member              : {is_member_1007}")
print(f"Kode Promo Tersedia        : {promo_tersedia_1007}")
print(f"Mendapatkan Diskon Member  : {diskon_member_1007}")
print(f"Mendapatkan Promo          : {dapat_promo_1007}")

# 5. OPERATOR ARITMATIKA
diskon_persen_1007 = 0.10 if diskon_member_1007 else 0.0
besar_diskon_1007 = total_1007 * diskon_persen_1007
total_bayar_1007 = total_1007 - besar_diskon_1007
rata_rata_1007 = total_bayar_1007 / jumlah_1007

# 6. OPERATOR PENUGASAN (termasuk augmented assignment)
akumulasi_bayar_1007 = 0
akumulasi_bayar_1007 += total_bayar_1007
akumulasi_bayar_1007 *= 1

print("\n===== HASIL PERHITUNGAN =====")
print(f"Diskon                     : Rp{besar_diskon_1007:.0f}")
print(f"Total Pembayaran           : Rp{total_bayar_1007:.0f}")
print(f"Rata-rata Harga Barang     : Rp{rata_rata_1007:.0f}")

# 7. OPERATOR IDENTITAS (is / is not)
obj_a_1007 = daftar_promo_1007
obj_b_1007 = daftar_promo_1007
obj_c_1007 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]

identitas_sama_1007 = obj_a_1007 is obj_b_1007
identitas_beda_1007 = obj_a_1007 is not obj_c_1007
nilai_sama_1007 = obj_a_1007 == obj_c_1007

# 8. OPERATOR BITWISE - Kode Status Transaksi
bit_member_1007 = 0b0001 if is_member_1007 else 0b0000
bit_belanja_1007 = 0b0010 if syarat_belanja_1007 else 0b0000
bit_barang_1007 = 0b0100 if syarat_barang_1007 else 0b0000
bit_promo_1007 = 0b1000 if promo_tersedia_1007 else 0b0000

# OR (|) menggabungkan seluruh kondisi menjadi satu kode status
kode_status_1007 = bit_member_1007 | bit_belanja_1007 | bit_barang_1007 | bit_promo_1007

# AND (&) memeriksa apakah kondisi tertentu aktif pada kode status
cek_member_1007 = kode_status_1007 & 0b0001
cek_promo_1007 = kode_status_1007 & 0b1000


# XOR (^) membandingkan perbedaan status terhadap kode referensi
kode_referensi_1007 = 0b1011
xor_status_1007 = kode_status_1007 ^ kode_referensi_1007

# Bitwise shift sebagai tambahan (bukan wajib, pelengkap)
shift_status_1007 = kode_status_1007 << 1

# Hak akses pelanggan berdasarkan bit
member_access_1007 = bool(cek_member_1007)
promo_access_1007 = bool(cek_promo_1007)
free_shipping_access_1007 = promo_1007 == "GRATISONGKIR"

print("\n===== HAK AKSES PELANGGAN =====")
print(f"Kode Status (biner)        : {bin(kode_status_1007)}")
print(f"Kode Status (desimal)      : {kode_status_1007}")
print(f"Member Access              : {member_access_1007}")
print(f"Promo Access               : {promo_access_1007}")
print(f"Free Shipping Access       : {free_shipping_access_1007}")

#=====OPERASI BITWISE=====
print("\n=== OPERASI BITWISE =====")

print("\n===== Kode Status Transaksi =====")

#KODE STATUS
#0001 = member
#0010 = total belanja >= Rp 200000
#0100 = jumlah barang >= 3
#1000 = promo

#menggunakan OR (|)
kode_transaksi_1007 =  int(is_member_1007) << 0 | int(syarat_belanja_1007) << 1 | int(syarat_barang_1007) << 2 | int(promo_tersedia_1007) << 3
kode_referensi_1007 = int(is_member_1007) << 0 | int(syarat_belanja_1007) << 1 | int(promo_tersedia_1007) << 3

print(f"{format(int(is_member_1007) << 0, '04b')} | {format(int(syarat_belanja_1007) << 1, '04b')} | {format(int(syarat_barang_1007) << 2, '04b')} | {format(int(promo_tersedia_1007) << 3, '04b')}")
print(f"Kode Biner   : {format(kode_transaksi_1007, '04b')}") 
print(f"Kode Desimal : {kode_transaksi_1007}")


#=====PEMERIKSAAN STATUS=====
print("\n===== Pemeriksaan Status =====")


print("\nCek Member")

#menggunakan and (&)

print(f"{format(kode_transaksi_1007, '04b')} & {format(int(is_member_1007) << 0, '04b')}")
print(f"Hasil Biner   : {format((kode_transaksi_1007) & int(is_member_1007) << 0, '04b')}")
print(f"Hasil Desimal : {(kode_referensi_1007) & int(is_member_1007) << 0}") 

print("\nCek Promo")

print(f"{format(kode_transaksi_1007, '04b')} & {format(int(promo_tersedia_1007) << 3, '04b')}")
print(f"Hasil Biner   : {format((kode_transaksi_1007) & int(promo_tersedia_1007) << 3, '04b')}")
print(f"Hasil Desimal  : {(kode_transaksi_1007) & int(promo_tersedia_1007) << 3}")


#=====PERBANDINGAN STATUS=====
print("\n===== Perbandingan Status =====")

 # menggunakan XOR (^)

print(f"Kode Transaksi : {format(kode_transaksi_1007, '04b')}")
print(f"Kode Referensi : {format(kode_referensi_1007, '04b')}")
print(f"{format(kode_transaksi_1007, '04b')} ^ {format(kode_referensi_1007, '04b')}")
print(f"Hasil Biner    : {format((kode_transaksi_1007) ^ (kode_referensi_1007))}")
print(f"Hasil Desimal  : {(kode_transaksi_1007) ^ (kode_referensi_1007)}")


#======SHIFT GESER KIRI=====
print("\n===== Shift =====")

#bitwise kiri/ shift kiri (<<)

print(f"{format(kode_transaksi_1007,'04b')} << 1")
print(f"Hasil Biner   : {format((kode_transaksi_1007) << 1,'04b')}")
print(f"Hasil Desimal : {(kode_transaksi_1007) << 1}") 

print("\n===== SELESAI =====")
# Out:
# ===== SISTEM TRANSAKSI TOKO =====
#
#
# ===== DATA TRANSAKSI =====
# Nama Pelanggan       : Rozi
# Status Pelanggan     : meber
# Total Belanja        : Rp300000.0
# Jumlah Barang        : 4
# Kode Promo           : HEMAT10
#
# ===== HASIL VALIDASI =====
# Belanja >= Rp200000        : True
# Jumlah Barang >= 3         : True
# Status Member              : False
# Kode Promo Tersedia        : True
# Mendapatkan Diskon Member  : False
# Mendapatkan Promo          : True
#
# ===== HASIL PERHITUNGAN =====
# Diskon                     : Rp0
# Total Pembayaran           : Rp300000
# Rata-rata Harga Barang     : Rp75000
#
# ===== HAK AKSES PELANGGAN =====
# Kode Status (biner)        : 0b1110
# Kode Status (desimal)      : 14
# Member Access              : False
# Promo Access               : True
# Free Shipping Access       : False
#
# === OPERASI BITWISE =====
#
# ===== Kode Status Transaksi =====
# 0000 | 0010 | 0100 | 1000
# Kode Biner   : 1110
# Kode Desimal : 14
#
# ...

# %% [markdown]
# ***A. Penjelasan :***
#
# *1. Input & Setup (baris 4-8, 18)*
# 4-8. Menerima input nama, status, total belanja, jumlah barang, dan kode promo dari pengguna (status dan promo tanpa normalisasi huruf/spasi).
# 18 Membuat daftar kode promo valid.
#
# *2. Output Data Transaksi (10-15)*
# Mencetak nama, status, total belanja, jumlah barang, dan kode promo yang diinput.
#
# *3. Operator Perbandingan (21-23)*
# 21-23. Mengecek: belanja ≥ 200000, jumlah barang ≥ 3, status == "member".
#
# *4. Operator Keanggotaan (26-27)*
# 26-27. Mengecek kode promo ada/tidak ada di daftar_promo dengan in/not in.
#
# *5. Operator Logika (31-33)*
# 31 Diskon member: member dan syarat belanja terpenuhi.
# 32 Dapat promo: promo tersedia dan (syarat belanja atau syarat barang).
# 33 Kebalikan status member (not).
#
# *6. Output Validasi (35-41) — Mencetak hasil dari baris 21-32.*
#
# *7. Operator Aritmatika (44-47)*
# 44-47. Menghitung persen diskon, besar diskon (kali), total bayar (kurang), rata-rata harga (bagi).
#
# *8. Operator Penugasan (50-52)*
# 50-52. Akumulasi total bayar memakai += dan *=.
#
# *9. Output Perhitungan (54-57) — Mencetak diskon, total bayar, rata-rata.*
#
# *10. Operator Identitas (60-66)*
# 60-61. Dua variabel menunjuk objek list yang sama.
# 62 Variabel baru dengan isi sama, objek beda.
# 64-66. is cek objek sama, is not cek objek beda, == cek nilai sama.
#
# *11. Operator Bitwise (69-92)*
# 69-72. Menentukan 4 bit kondisi (member, belanja, barang, promo).
# 75 Gabung semua bit jadi kode status (|).
# 78-79. Cek bit tertentu aktif (&).
# 83-84. Bandingkan kode status dengan referensi (^).
# 87 Geser bit ke kiri (<<).
# 90-92. Tentukan hak akses dari hasil cek bit.
#
# *12. Output Hak Akses (94-99) — Mencetak kode status, hasil cek, dan hak akses.*
#
# *13. Demo Bitwise Tambahan (102-159)*
# 113-114. Membangun ulang kode_transaksi dan kode_referensi dengan cara shift manual (kode_referensi sengaja tidak menyertakan bit barang).
# 116-118. Menampilkan bit-per-bit dan kode gabungan.
# 129-137. Demonstrasi AND untuk cek member dan cek promo (baris 131 ada inkonsistensi: pakai kode_referensi, bukan kode_transaksi).
# 145-149. Demonstrasi XOR (baris 148 ada bug: lupa format '04b' sehingga hasil tidak tampil biner).
# 157-159. Demonstrasi shift kiri (<<).
#
# Mencetak pesan penutup program.
#
# ***B. Analisis Pada Laporan***
#
# **Soal :**
#
# <div align="center">
# <img src="images/foto_soal_analisis.png" width="500"><br>
# <em>Gambar 2.3 : Soal Analisis Laporan</em>
# </div>
#
#
# *1. Operator aritmatika yang digunakan dan perannya dalam menghitung transaksi*
# Program menggunakan operator perkalian (*) untuk menghitung besar diskon (total_1007 dikali diskon_persen_1007), pengurangan (-) untuk mendapatkan total pembayaran setelah diskon (total_1007 dikurang besar_diskon_1007), pembagian (/) untuk menghitung rata-rata harga per barang (total_bayar_1007 dibagi jumlah_1007), dan modulus (%) untuk mendapatkan sisa pembagian jumlah barang terhadap 3 (jumlah_1007 modulus 3). Keempat operator ini mengubah data mentah (total belanja dan jumlah barang) menjadi informasi transaksi yang bisa langsung ditampilkan ke pelanggan.
#
# *2. Perbedaan operator and, or, dan not*
# and menghasilkan True hanya jika kedua kondisi bernilai True — dipakai pada diskon_member_1007 sama dengan is_member_1007 and syarat_belanja_1007, artinya diskon member hanya didapat jika pelanggan memang member dan belanjanya memenuhi minimum. or menghasilkan True jika salah satu kondisi terpenuhi — dipakai pada dapat_promo_1007 sama dengan promo_tersedia_1007 and (syarat_belanja_1007 or syarat_barang_1007), artinya promo bisa didapat asal salah satu dari syarat belanja atau syarat barang terpenuhi. not membalik nilai boolean — dipakai pada bukan_member_1007 sama dengan not is_member_1007 untuk menandai pelanggan yang bukan member.
#
# *3. Fungsi operator in dan not in pada pemeriksaan kode promo*
# in (pada baris promo_tersedia_1007 sama dengan promo_1007 in daftar_promo_1007) memeriksa apakah kode promo yang diinput pelanggan terdaftar dalam daftar_promo_1007, menghasilkan True jika kode tersebut valid. not in (pada baris promo_tidak_tersedia_1007 sama dengan promo_1007 not in daftar_promo_1007) memeriksa kebalikannya, yaitu memastikan kode promo tidak terdaftar — berguna untuk mendeteksi input kode promo yang salah atau tidak dikenali.
#
# *4. Perbedaan is dan ==*
# is membandingkan identitas objek, yaitu apakah dua variabel menunjuk ke lokasi memori yang sama persis. == membandingkan nilai atau isi objek, terlepas dari objeknya sama atau tidak. Dalam program, obj_a_1007 dan obj_b_1007 sama-sama menunjuk ke daftar_promo_1007, sehingga obj_a_1007 is obj_b_1007 bernilai True. Sebaliknya, obj_c_1007 dibuat sebagai list baru dengan isi identik, sehingga obj_a_1007 is obj_c_1007 bernilai False karena objeknya berbeda, tetapi obj_a_1007 == obj_c_1007 tetap True karena isinya sama.
#
# *5. Penggunaan operator bitwise untuk menentukan hak akses pelanggan*
# Empat kondisi pelanggan (member, syarat belanja, syarat barang, promo tersedia) masing-masing diwakili satu bit, yaitu 0001, 0010, 0100, dan 1000. Operator OR menggabungkan seluruh bit yang aktif menjadi satu kode_status_1007. Operator AND lalu dipakai untuk memeriksa apakah bit tertentu aktif pada kode status tersebut — kode_status_1007 AND 0001 untuk memastikan status member yang menghasilkan member_access_1007, dan kode_status_1007 AND 1000 untuk memastikan promo tersedia yang menghasilkan promo_access_1007. Hasil AND ini kemudian diubah ke boolean untuk dijadikan penentu hak akses. Operator XOR juga dipakai untuk membandingkan kode status pelanggan dengan kode referensi, menunjukkan bit mana yang berbeda antara keduanya.
#
# *6. Alur program dari input hingga total pembayaran dan status promo*
# Program dimulai dengan menerima input nama, status, total belanja, jumlah barang, dan kode promo. Operator perbandingan lalu memeriksa apakah total belanja dan jumlah barang memenuhi syarat minimum, serta apakah pelanggan berstatus member. Operator keanggotaan memeriksa apakah kode promo terdaftar di daftar_promo_1007. Hasil-hasil boolean tersebut digabungkan dengan operator logika untuk menentukan status diskon member dan kelayakan promo. Selanjutnya operator aritmatika menghitung besar diskon, total pembayaran, dan rata-rata harga barang, sementara operator penugasan (augmented assignment) memperbarui poin dan akumulasi pembayaran. Terakhir, operator bitwise membentuk kode status transaksi yang menjadi dasar hak akses pelanggan, dan seluruh hasil ditampilkan sebagai output.
#
# *7. Contoh kondisi bernilai True dan False*
# Misalnya untuk pelanggan dengan total belanja Rp250.000, member, 4 barang, kode promo HEMAT10: kondisi syarat_belanja_1007 sama dengan total_1007 lebih besar atau sama dengan 200000 bernilai True, karena Rp250.000 melebihi batas minimum Rp200.000. Sebaliknya, kondisi bukan_member_1007 sama dengan not is_member_1007 bernilai False, karena pelanggan tersebut memang berstatus member (is_member_1007 bernilai True, sehingga negasinya False).

# %% [markdown]
# ---
# # <h1 align = "center">BAB III <h1>
# # <h1 align = "center">KESIMPULAN <h1>
#
# Berdasarkan praktikum dan studi kasus sistem simulasi transaksi dan validasi akses toko yang telah dikerjakan, dapat disimpulkan bahwa ketujuh jenis operator dalam Python — aritmatika, penugasan, perbandingan, logika, keanggotaan, identitas, dan bitwise — memiliki peran yang saling melengkapi dan dapat diintegrasikan dalam satu alur program yang utuh.
#
# Operator perbandingan dan logika berperan penting dalam tahap validasi, yaitu menentukan apakah pelanggan memenuhi syarat minimum belanja, jumlah barang, dan status member, sekaligus menggabungkan beberapa kondisi tersebut untuk menentukan kelayakan diskon dan promo. Operator aritmatika dan penugasan menangani seluruh perhitungan transaksi, mulai dari besar diskon, total pembayaran, rata-rata harga barang, hingga pembaruan poin pelanggan secara ringkas melalui augmented assignment. Operator keanggotaan memastikan validitas kode promo terhadap daftar yang tersedia, sementara operator identitas membuktikan secara konkret perbedaan mendasar antara `is` (identitas objek) dan `==` (kesamaan nilai), yang sering menjadi sumber kesalahan logika bagi pemula. Terakhir, operator bitwise digunakan untuk membangun kode status transaksi berbasis bit, yang menjadi dasar penentuan hak akses pelanggan secara efisien.
#
# Secara keseluruhan, praktikum ini menunjukkan bahwa pemahaman operator bukan sekadar hafalan simbol, melainkan kemampuan memilih operator yang tepat sesuai kebutuhan logika program — sebuah bekal penting sebelum mahasiswa melanjutkan ke materi struktur kontrol seperti percabangan dan perulangan.

# %% [markdown]
# ---
# ## <h1 align = "center">DAFTAR PUSAKA <h1>
#
# [1] DQLab. (2021, 21 Desember). Tutorial Python: Pelajari 7 jenis operator ini, dijamin jago ngoding!. https://dqlab.id/tutorial-python-pelajari-7-jenis-operator-ini-dijamin-jago-ngoding
#
# [2] Ediweb.dev. (2024, 2 November). Panduan lengkap mengenal operator Python: Aritmatika, penugasan, logika, dan lainnya. https://ediweb.dev/python/belajar-dasar-python-jenis-operator
#
# [3] Jago Ngoding. (2021, 15 Mei). Python dasar: 7 jenis operator. https://jagongoding.com/python/dasar/operator/
#
# [4] RevoU. (2024, 24 Desember). 7 jenis operator Python, fungsi, dan contohnya. https://www.revou.co/panduan-teknis/operator-python
#
# [5] Duniailkom. (2019, 30 Juli). Tutorial belajar Python: Jenis-jenis operator bitwise Python. https://www.duniailkom.com/tutorial-belajar-python-jenis-jenis-operator-bitwise-python/
